# %% [markdown]
# ## **Text-to-speech**

# %% [markdown]
# ### **Japanese**

# %%
import IPython.display as ipd
from tts import synthesize

# %%
text = "これこそが知恵の殿堂。私のおうちにいっらしゃい。知識をあなたにも。"

audio = synthesize(text, lang="ja")

# %%
ipd.display(ipd.Audio(audio, rate=22050, normalize=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **Denoising**

# %%
import IPython.display as ipd
from se import denoise

# %%
noisy_audio_path = "/Users/hurui05/Desktop/projects/lemon5/samples/sample_input/sovits_src.wav"
clean_audio = denoise(noisy_audio_path)

# %%
ipd.display(ipd.Audio(clean_audio, rate=16000, normalize=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
